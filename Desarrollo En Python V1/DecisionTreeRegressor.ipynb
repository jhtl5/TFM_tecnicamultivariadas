# %% [markdown]
# **texto en negrita**<h2><font color="#004D7F" size=6>TFM -Estudio de modelos de predicción, para la gestión de tiempos correctivos en una empresa Industrial.
#
#
# <h1><font color="#004D7F" size=5>DecisionTreeRegressor</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#004D7F" size=3>Jose Humberto Torres</font><br>
# <font color="#004D7F" size=3>TFM</font><br>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container{ width:98% }</style>"))
# Out:
# <style>.container{ width:98% }</style>

# %% [markdown]
# ---
#
# <a id="section1"></a>
# # <font color="#004D7F"> 1. Introducción</font>

# %% [markdown]
# En esta libreta se muestra una predicción de las HH Que se necesitan para mantenimiento correctivo en una empresa del sector industrial, la frecuencia es semanal, a continuación, se hace na breve descripción de la base de datos.:
#
# * **semana:** Hace referencia a la semana del año en la cual se ejecuta el trabajo - se codifica con nombre del año seguido del número de la semana, un año por lo general tiene 52 semanas.
# * **Disciplina:** La disciplina se refiera al grupo e equipo de trabajo que realiza mantenimientos en la presa, la empresa está dividida en 7 disciplinas: Pozos, Instrumentos, Mecánica, Mecánica VAL, Electricidad, Línea de Mtto, Mecánica CBM
# * **Epocadelanio:** Esta variable hace referencia a la época del año en que se ejecuta el mantenimiento, generalmente son dos estaciones Invierno y verano.
# * **Cumplimiento_Estrategia:** Se refiere al cumplimiento del plan de estrategia de mantenimiento preventivo ejecutado en el mes.
# * **Cumplimiento_Programa:** Se refiere al cumplimiento del programa de mantenimiento ejecutado en el mes.
# * **Ready_Backlog:** Es la carga de trabajo que tienen un equipo de trabajo, se mide en semanas
# * **HH_Actv_Gnerales:** son las horas hombres que reportan en actividades generales, esta variable cuantitativa se por actividades como charlas de seguridad, celebraciones, reuniones entre otros.
# * **HH_En_la_Maquina:** Es la variable objetivo y hace referencia al total de horas que el técnico necesita para ejecutar un trabajo en la maquina o equipo a reparar.
# * **Otras_HH:** Esta variable se refiere a las horas adicionales que se requieren para hacer actividades propias del mantenimiento como lectura de permisos, transporte a sitio, alistamiento de herramientas entre otros.

# %% [markdown]
# <a id="section11"></a>
# ## <font color="#004D7F"> 1.1. Importar librerías</font>

# %% [markdown]
# Se importan los módulos y las librerías necesarias para este proceso.

# %%
# Load libraries
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
# codigo para conectar con google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <a id="section12"></a>
# ## <font color="#004D7F"> 1.2. Cargar el dataset</font>

# %% [markdown]
# se cargan los datos de ventas, los cuales estan en formato CSV. Y  guardan en una Variable dataset - Que corresponde al DataFrame a trabajar.

# %%
# Load dataset
# se cargan los datos de ventas, los cuales estan en formato CSV. Y  guardan en una Variable df - Que corresponde al DataFrame a trabajar.
dataset = pd.read_csv('/content/drive/MyDrive/InfoTFM/semana.csv',index_col=0, sep=',', encoding='latin-1')

# %% [markdown]
# <div style="text-align: right"> <font size=5>
#     <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a>
# </font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F"> 2. Estadística descriptiva</font>

# %% [markdown]
# Se analizan las diferentes variables y caracteristicas como:
# * Dimensiones del conjunto de datos.
# * Visualización de datos.
# * Resumen estadístico de todos los atributos.
# * Coorelación de atributos numéricos.
# * Tipo de atributos.
#
# Nota: La base de datos para este caso se le practico un proceso de limpieza y agrupación en el script de R.

# %% [markdown]
# <a id="section21"></a>
# ## <font color="#004D7F"> 2.1. Dimensiones del conjunto de datos</font>

# %% [markdown]
# Podemos tener una idea rápida de cuántas instancias (filas) y cuántos atributos (columnas) hay en nuestro conjunto de datos con la propiedad `shape`.  Donde se aprecia que el dataset cuanta con un total de 984 filas y  8 columnas.

# %%
# shape
dataset.shape
# Out:
# (984, 8)

# %% [markdown]
# <a id="section22"></a>
# ## <font color="#004D7F"> 2.2. Visualización de datos</font>

# %% [markdown]
# También siempre es una buena idea ver como están representados los datos con la función `head()`

# %%
# head
dataset.head(5)
# Out:
#            Disciplina Epocadelanio  Cumplimiento_Estrategia  \
# semana
# 2019-1   Instrumentos       Verano                     0.98
# 2019-10         Pozoz       Verano                     0.99
# 2019-11  Instrumentos       Verano                     0.99
# 2019-12  Instrumentos       Verano                     0.99
# 2019-12      Mecanica       Verano                     0.99
#
#          Cumplimiento_Programa  Ready_Backlog  HH_Actv_Gnerales  \
# semana
# 2019-1                    0.95           5.16              0.37
# 2019-10                   0.92           4.67              0.30
# 2019-11                   0.92           4.67              0.20
# 2019-12                   0.92           4.67              1.05
# 2019-12                   0.92           4.67              0.70
#
#          HH_En_la_Maquina  Otras_HH
# semana
# 2019-1               3.27      0.67
# 2019-10              1.80      1.90
# 2019-11              0.50      0.00
# 2019-12              8.00      1.55
# 2019-12              9.00      1.30

# %%
# Tambien se puede observar - los diferentes nombres de las columas.
dataset = dataset.reset_index()

dataset.columns
# Out:
# Index(['semana', 'Disciplina', 'Epocadelanio', 'Cumplimiento_Estrategia',
#        'Cumplimiento_Programa', 'Ready_Backlog', 'HH_Actv_Gnerales',
#        'HH_En_la_Maquina', 'Otras_HH'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   semana                   984 non-null    object
#  1   Disciplina               984 non-null    object
#  2   Epocadelanio             984 non-null    object
#  3   Cumplimiento_Estrategia  984 non-null    float64
#  4   Cumplimiento_Programa    984 non-null    float64
#  5   Ready_Backlog            984 non-null    float64
#  6   HH_Actv_Gnerales         984 non-null    float64
#  7   HH_En_la_Maquina         984 non-null    float64
#  8   Otras_HH                 984 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 69.3+ KB

# %%
dataset.isna().sum().sort_values()
# Out:
# semana                     0
# Disciplina                 0
# Epocadelanio               0
# Cumplimiento_Estrategia    0
# Cumplimiento_Programa      0
# Ready_Backlog              0
# HH_Actv_Gnerales           0
# HH_En_la_Maquina           0
# Otras_HH                   0
# dtype: int64

# %% [markdown]
# **Grafico de datos:** Se realiza un gráfico donde se puede observar en la parte X - El numero de la semana y en el eje Y - El total de horas hombre efectivas en la máquina - que es la variable a respuesta.

# %%
plt.scatter(dataset['semana'],dataset['HH_En_la_Maquina'])
plt.show()

# %% [markdown]
# <a id="section23"></a>
# ## <font color="#004D7F"> 2.3. Resumen estadístico</font>

# %% [markdown]
# En este caso podemos echar un vistazo a un resumen de cada atributo con la función `describe()`. Esto incluye la media, los valores mínimo y máximo, así como algunos percentiles.

# %%
# descriptions
pd.set_option('display.precision', 1)
dataset.describe()
# Out:
#        Cumplimiento_Estrategia  Cumplimiento_Programa  Ready_Backlog  \
# count                  9.8e+02                9.8e+02          984.0
# mean                   9.9e-01                9.5e-01            5.3
# std                    1.1e-02                2.0e-02            0.6
# min                    9.5e-01                9.1e-01            4.0
# 25%                    9.9e-01                9.4e-01            4.8
# 50%                    9.9e-01                9.5e-01            5.3
# 75%                    1.0e+00                9.7e-01            5.6
# max                    1.0e+00                9.9e-01            6.7
#
#        HH_Actv_Gnerales  HH_En_la_Maquina  Otras_HH
# count             984.0             984.0     984.0
# mean                0.7               8.1       2.0
# std                 0.3               3.3       1.0
# min                 0.0               0.5       0.0
# 25%                 0.5               6.0       1.4
# 50%                 0.7               7.6       1.9
# 75%                 0.9              10.0       2.5
# max                 2.0              22.0       6.0

# %% [markdown]
# <a id="section24"></a>
# ## <font color="#004D7F"> 2.4. Tipo de datos</font>
#
# Se puede observar el tipo de datos de cada una de la variables y adicionalmente se convierte la variable Epocadelanio en binaria 1 y  0 : 1 Para Verano y 2: Invierno.

# %%
dataset['Disciplina'] = dataset['Disciplina'].astype("object")

# %%
# Convertir variable categorica ciudad en 1 y 0
Epocadelanio = {'Invierno':0,'Verano':1}

dataset['Epocadelanio']=dataset['Epocadelanio'].map(Epocadelanio)

# %% [markdown]
# Podemos ver el tipo de variable de cada atributo con la propiedad `dtypes`.

# %%
# tipo de datos de las variables.
dataset.dtypes
# Out:
# semana                      object
# Disciplina                  object
# Epocadelanio                 int64
# Cumplimiento_Estrategia    float64
# Cumplimiento_Programa      float64
# Ready_Backlog              float64
# HH_Actv_Gnerales           float64
# HH_En_la_Maquina           float64
# Otras_HH                   float64
# dtype: object

# %%
dataset.isna().sum().sort_values()
# Out:
# semana                     0
# Disciplina                 0
# Epocadelanio               0
# Cumplimiento_Estrategia    0
# Cumplimiento_Programa      0
# Ready_Backlog              0
# HH_Actv_Gnerales           0
# HH_En_la_Maquina           0
# Otras_HH                   0
# dtype: int64

# %%
# Se observan los datos con la variable epoca del año 1 y 0.
dataset.head(444)
# Out:
#       semana    Disciplina  Epocadelanio  Cumplimiento_Estrategia  \
# 0     2019-1  Instrumentos             1                      1.0
# 1    2019-10         Pozoz             1                      1.0
# 2    2019-11  Instrumentos             1                      1.0
# 3    2019-12  Instrumentos             1                      1.0
# 4    2019-12      Mecanica             1                      1.0
# ..       ...           ...           ...                      ...
# 439  2021-35  Electricidad             0                      1.0
# 440  2021-35  Instrumentos             0                      1.0
# 441  2021-37  Electricidad             0                      1.0
# 442  2021-37  Instrumentos             0                      1.0
# 443  2021-37      Mecanica             0                      1.0
#
#      Cumplimiento_Programa  Ready_Backlog  HH_Actv_Gnerales  HH_En_la_Maquina  \
# 0                      0.9            5.2               0.4               3.3
# 1                      0.9            4.7               0.3               1.8
# 2                      0.9            4.7               0.2               0.5
# 3                      0.9            4.7               1.1               8.0
# 4                      0.9            4.7               0.7               9.0
# ..                     ...            ...               ...               ...
# 439                    1.0            5.5               0.5               7.0
# 440                    1.0            5.5               0.5               4.0
# 441                    1.0            5.5               0.6               7.2
# 442                    1.0            5.5               0.3               5.8
# 443                    1.0            5.5               0.8               7.0
#
#      Otras_HH
# 0         0.7
# 1         1.9
# 2         0.0
# 3         1.6
# 4         1.3
# ..        ...
# 439       1.5
# 440       0.6
# 441       1.7
# 442       0.5
# 443       1.4
#
# [444 rows x 9 columns]

# %% [markdown]
# <div style="text-align: right"> <font size=5>
#     <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a>
# </font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F"> 3. Visualización del conjunto de datos</font>

# %% [markdown]
# Ahora tenemos una idea básica sobre los datos. Necesitamos extender eso con algunas visualizaciones. Vamos a ver dos tipos de gráficos de visualización de datos:
# * Gráficos univariados para comprender mejor cada atributo.
# * Gráficos multivariados para comprender mejor las relaciones entre los atributos.

# %% [markdown]
# <a id="section31"></a>
# ## <font color="#004D7F"> 3.1. Gráficos Univariados</font>

# %% [markdown]
# Comenzamos con algunas gráficas univariadas, es decir, gráficas de cada variable individual. Es útil con la visualización tener una forma de referirse solo a los atributos de entrada y, por otro lado, solo a los atributos de salida.

# %% [markdown]
# <a id="section311"></a>
# ### <font color="#004D7F"> Boxplots</font>
# Dado que las variables de entrada son numéricas, podemos crear Gráficas Boxplots de cada uno.
#
# Nota: Se puede observar que aún existen valores atípicos, por tanto se va usar una función para rastreo del mejor percentil superior para ajuste de outlayers superiores e inferiores.

# %%
# box and whisker plots - Matplotlib
fig = plt.figure(figsize = (20,20))
ax = fig.gca()
dataset.plot(ax=ax, kind= 'box', subplots=True, layout=(4,4))
plt.show()

# %%
# ----- Funcion para rastreo del mejor percentil superior para ajuste de outlayers superiores
def HallaMejorPercentilSup(micol,  maximo, minimo, miCotaSup, dataframeA):
	for x in range(maximo, minimo, -1):
		valor_tope_actual = np.quantile(dataframeA.iloc[:,micol] , x/100)
		print(f"Percentil {x} = {np.round_(valor_tope_actual,micol)},col = {micol}, CotaSup = {miCotaSup}")
		if(valor_tope_actual <= miCotaSup):
			return x , valor_tope_actual

# %%
# Proceso de correccion de Outlier Superior.

columnas =  [6,7,8]
for col in columnas:
  q3=np.quantile(dataset.iloc[ : , col] , 0.75)
  q1=np.quantile(dataset.iloc[ : , col] , 0.25)
  IQR=q3-q1
  CotaSup=q3+1.5*IQR
  PercentilSupSugerido , ValorTecho = HallaMejorPercentilSup(col, 99, 70, CotaSup, dataset)
  dataset.iloc[ : , col] = np.where(dataset.iloc[ : , col] > ValorTecho, ValorTecho, dataset.iloc[ : , col] )
# Out:
# Percentil 99 = 1.917,col = 6, CotaSup = 1.4300000000000002
# Percentil 98 = 1.5,col = 6, CotaSup = 1.4300000000000002
# Percentil 97 = 1.5,col = 6, CotaSup = 1.4300000000000002
# Percentil 96 = 1.3436,col = 6, CotaSup = 1.4300000000000002
# Percentil 99 = 17.585,col = 7, CotaSup = 16.0
# Percentil 98 = 16.0,col = 7, CotaSup = 16.0
# Percentil 99 = 5.4,col = 8, CotaSup = 4.21
# Percentil 98 = 5.0,col = 8, CotaSup = 4.21
# Percentil 97 = 4.5,col = 8, CotaSup = 4.21
# Percentil 96 = 4.2,col = 8, CotaSup = 4.21

# %%
# Ahora se observa que los valores atipicos superiores no existen.
fig = plt.figure(figsize = (20,20))
ax = fig.gca()
dataset.plot(ax=ax, kind= 'box', subplots=True, layout=(4,4))
plt.show()

# %% [markdown]
# Esto ayuda a señalar el sesgo en muchas distribuciones tanto que los datos se ven como valores atípicos (por ejemplo, más allá del bigote de los gráficos).

# %% [markdown]
# <a id="section311"></a>
# ### <font color="#004D7F"> Histograma</font>
# También podemos crear un histograma de cada variable de entrada para tener una idea de la distribución.

# %%
# histograms - Matplotlib
fig = plt.figure(figsize = (20,20))
ax = fig.gca()
dataset.hist(ax=ax)
plt.show()

# %% [markdown]
# Podemos ver que algunos atributos pueden tener una distribución exponencial, como `CRIM`, `ZN`, `AGE` y `B`. Podemos ver que otros pueden tener una distribución bimodal como `RAD` y `TAX`.

# %% [markdown]
# Esto quizás agrega más evidencia a nuestra sospecha sobre posibles distribuciones exponenciales y bimodales. También parece que `NOX`, `RM` y `LSTAT` pueden tener distribuciones gaussianas sesgadas, lo que podría ser útil más adelante con las transformaciones.

# %% [markdown]
# <a id="section32"></a>
# ## <font color="#004D7F"> 3.2. Gráficos multivariados</font>

# %% [markdown]
# Ahora podemos ver las interacciones entre las variables.

# %% [markdown]
# <a id="section321"></a>
# ### <font color="#004D7F"> Diagramas de dispersión</font>
# Primero veamos los diagramas de dispersión de todos los pares de atributos y coloreamos los puntos por clase. Además, como los gráficos de dispersión muestran que los puntos para cada clase generalmente están separados, podemos dibujar puntos suspensivos alrededor de ellos.
#
# Ahora podemos ver las interacciones entre las variables. Veamos gráficos de dispersión de todos los pares de atributos. Esto puede ser útil para detectar relaciones estructuradas entre variables de entrada. Tenga en cuenta la agrupación diagonal de algunos pares de atributos. Esto sugiere una alta correlación y una relación predecible.

# %%
# scatter plot matrix - Matplotlib
plt.rcParams["figure.figsize"] = [15,15]
pd.plotting.scatter_matrix(dataset)
plt.show()

# %% [markdown]
# <div style="text-align: right"> <font size=5>
#     <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a>
# </font></div>
#
# ---

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F"> 4. Fase de modelado</font>

# %% [markdown]
# Ahora es el momento de crear algunos modelos de datos y estimar su Accruacy en datos no etiquetados. Esto es lo que vamos a cubrir en este paso:
# * Crear conjunto de validación.
# * Evaluación de línea base.
# * Evaluar algoritmos: Estandarización.

# %% [markdown]
# <a id="section41"></a>
# ## <font color="#004D7F"> 4.1. Crear conjunto de validación</font>

# %%
plt.scatter(dataset['semana'],dataset['HH_En_la_Maquina'])
plt.show()

# %% [markdown]
# Es una buena idea utilizar un conjunto de validación. Esta es una muestra de los datos que retenemos de nuestro análisis y modelado. Lo usamos justo al final de nuestro proyecto para confirmar el Accuracy de nuestro modelo final. Es una prueba que podemos usar para ver si nos equivocamos y para darnos confianza en nuestras estimaciones de Accuracy en datos no etiquetados. Dividiremos el conjunto de datos cargado en dos, el 90% de los cuales utilizaremos para entrenar nuestros modelos y el 10% como un conjunto de datos de validación.

# %%
# Se crea este codigo para ver la posicion de l
posicion_variable = dataset.columns.get_loc('HH_En_la_Maquina')
posicion_variable
# Out:
# 7

# %%
dataset=dataset.drop('semana', axis=1)

# %%
dataset=dataset.drop('Disciplina', axis=1)

# %%
from sklearn.model_selection import train_test_split



X_train, X_test, y_train, y_test = train_test_split(
                                        dataset.drop('HH_En_la_Maquina', axis = 'columns'),
                                        dataset['HH_En_la_Maquina'],
                                        train_size   = 0.9,
                                        random_state = 1234,
                                        shuffle      = True
                                    )

# %%
# Se muestran los datos almacenados en la varaible  De entrenamiento.
X_train
# Out:
#      Epocadelanio  Cumplimiento_Estrategia  Cumplimiento_Programa  \
# 917             1                      1.0                    0.9
# 241             1                      1.0                    1.0
# 571             1                      1.0                    1.0
# 732             1                      1.0                    1.0
# 495             1                      1.0                    1.0
# ..            ...                      ...                    ...
# 204             0                      1.0                    0.9
# 53              0                      1.0                    0.9
# 294             1                      1.0                    1.0
# 723             1                      1.0                    1.0
# 815             0                      1.0                    1.0
#
#      Ready_Backlog  HH_Actv_Gnerales  Otras_HH
# 917            4.0               0.7       0.9
# 241            5.9               0.5       4.2
# 571            4.8               1.2       1.7
# 732            5.1               0.6       2.2
# 495            5.3               0.8       2.2
# ..             ...               ...       ...
# 204            6.6               0.3       0.9
# 53             5.9               0.5       1.2
# 294            5.7               0.5       1.3
# 723            5.3               1.3       1.5
# 815            4.8               0.8       2.4
#
# [885 rows x 6 columns]

# %%
# Se muestran los datos almacenados en la variable de validación.
X_test
# Out:
#      Epocadelanio  Cumplimiento_Estrategia  Cumplimiento_Programa  \
# 166             0                      1.0                    0.9
# 392             0                      1.0                    1.0
# 40              1                      1.0                    0.9
# 118             1                      1.0                    0.9
# 953             1                      1.0                    1.0
# ..            ...                      ...                    ...
# 146             0                      1.0                    0.9
# 891             0                      1.0                    1.0
# 867             0                      1.0                    0.9
# 93              1                      1.0                    0.9
# 450             0                      1.0                    1.0
#
#      Ready_Backlog  HH_Actv_Gnerales  Otras_HH
# 166            5.3           2.0e-01       1.4
# 392            4.7           8.0e-02       0.0
# 40             5.2           4.0e-01       1.6
# 118            5.3           7.7e-01       2.5
# 953            4.5           2.5e-01       1.5
# ..             ...               ...       ...
# 146            6.7           6.2e-01       1.4
# 891            5.3           6.6e-01       1.5
# 867            4.9           5.0e-01       1.5
# 93             5.9           8.5e-01       2.8
# 450            5.5           5.8e-01       2.4
#
# [99 rows x 6 columns]

# %%
# Se muestran los datos de la variable Y_train.
y_train
# Out:
# 917     5.9
# 241    14.0
# 571    10.5
# 732    11.0
# 495     7.5
#        ...
# 204     5.0
# 53      7.3
# 294     5.0
# 723     7.0
# 815     9.2
# Name: HH_En_la_Maquina, Length: 885, dtype: float64

# %%
y_test
# Out:
# 166     6.0
# 392     2.0
# 40      1.0
# 118     9.8
# 953     6.8
#        ...
# 146     5.7
# 891    11.8
# 867    16.0
# 93      7.0
# 450    10.5
# Name: HH_En_la_Maquina, Length: 99, dtype: float64

# %% [markdown]
# **Información de las variables:** con las siguientes lineas de código se muestra la información almacenada en cada una de las variables.

# %%
print('La forma de X_train es: ', X_train.shape)
print('La forma de y_train es: ', y_train.shape)
print('La forma de X_test es: ', X_test.shape)
print('La forma de y_test es: ', y_test.shape)
# Out:
# La forma de X_train es:  (885, 6)
# La forma de y_train es:  (885,)
# La forma de X_test es:  (99, 6)
# La forma de y_test es:  (99,)

# %% [markdown]
# <a id="section43"></a>
# ## <font color="#004D7F"> 4.3. Evaluar modelos: estandarización</font>

# %% [markdown]
# Sospechamos que las diferentes distribuciones de los datos en bruto pueden estar afectando negativamente a la habilidad de algunos de los algoritmos. Vamos a evaluar los mismos algoritmos con una copia estandarizada del conjunto de datos. Aquí es donde los datos se transforman de manera que cada atributo tenga un valor medio de cero y una desviación estándar de uno.
#
# También debemos evitar la fuga de datos cuando transformamos los datos. Una buena manera de evitar fugas es usar Pipelines que estandaricen los datos y construyan el modelo para cada _fold_ de la validación cruzada. De esa forma podemos obtener una estimación justa de cómo cada modelo con datos estandarizados podría funcionar en datos no vistos.

# %%
# Normalización con MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = y_train
X_test
# Out:
# array([[0.        , 0.8       , 0.5       , 0.4981685 , 0.14885383,
#         0.33333333],
#        [0.        , 0.8       , 0.625     , 0.27472527, 0.05954153,
#         0.        ],
#        [1.        , 0.6       , 0.5       , 0.44322344, 0.29770765,
#         0.38095238],
#        [1.        , 0.8       , 0.25      , 0.4981685 , 0.57308723,
#         0.59047619],
#        [1.        , 0.6       , 1.        , 0.19047619, 0.18606728,
#         0.35714286],
#        [1.        , 0.8       , 0.375     , 0.        , 0.22328074,
#         0.29761905],
#        [0.        , 1.        , 0.75      , 0.57875458, 0.86335219,
#         0.68333333],
#        [1.        , 0.8       , 0.625     , 0.5970696 , 0.        ,
#         0.47619048],
#        [1.        , 0.8       , 0.25      , 0.71794872, 0.37213456,
#         1.        ],
#        [0.        , 1.        , 0.75      , 0.3040293 , 0.37213456,
#         0.35      ],
#        [1.        , 1.        , 0.875     , 0.38461538, 0.48377493,
#         0.44047619],
#        [1.        , 0.8       , 0.625     , 0.21978022, 0.62518607,
#         0.51666667],
#        [1.        , 0.8       , 0.        , 0.72527473, 0.10419768,
#         0.13571429],
#        [1.        , 0.8       , 0.25      , 0.4981685 , 0.61774338,
#         0.66666667],
#        [1.        , 0.8       , 0.375     , 0.52014652, 0.61774338,
#         0.73095238],
#        [0.        , 0.8       , 0.5       , 0.34065934, 0.48377493,
#         0.10714286],
#        [1.        , 1.        , 0.625     , 0.64468864, 0.49866032,
#         0.53095238],
#        [1.        , 0.8       , 0.375     , 0.52747253, 0.41679071,
#         0.34285714],
#        [0.        , 0.8       , 0.5       , 0.4981685 , 0.3423638 ,
#         0.19285714],
#        [0.        , 1.        , 0.5       , 0.57509158, 0.44656148,
#         0.5547619 ],
#        [0.        , 0.8       , 0.375     , 0.67032967, 0.5954153 ,
#         0.79761905],
#        [1.        , 0.2       , 1.        , 0.04029304, 1.        ,
#         0.21428571],
#        [0.        , 0.8       , 0.375     , 0.4981685 , 0.58052992,
#         0.42857143],
#        [0.        , 0.8       , 0.5       , 0.34065934, 0.52098839,
#         0.43571429],
#        [1.        , 1.        , 0.375     , 0.61538462, 0.20095266,
#         0.26904762],
#        [0.        , 0.8       , 0.25      , 1.        , 0.5954153 ,
#         0.35714286],
#        [0.        , 0.6       , 0.75      , 0.4981685 , 0.54331646,
#         0.7547619 ],
#        [0.        , 0.8       , 0.5       , 0.34065934, 0.64751414,
#         0.45952381],
#        [0.        , 1.        , 0.75      , 0.27472527, 0.37957726,
#         0.32142857],
#        [1.        , 0.6       , 1.        , 0.19047619, 0.74426913,
#         0.77857143],
#        [0.        , 1.        , 0.75      , 0.3040293 , 1.        ,
#         0.28571429],
#        [1.        , 0.8       , 0.5       , 0.54578755, 0.75915451,
#         0.54761905],
#        [0.        , 0.6       , 0.75      , 0.4981685 , 0.14885383,
#         0.14285714],
#        [0.        , 0.        , 0.375     , 0.82417582, 0.66239952,
#         0.49285714],
#        [1.        , 1.        , 0.625     , 0.64468864, 0.4242334 ,
#         0.45      ],
#        [1.        , 1.        , 0.625     , 0.84249084, 0.6847276 ,
#         0.45714286],
#        [1.        , 0.8       , 0.375     , 0.52747253, 0.3423638 ,
#         0.53095238],
#        [0.        , 0.8       , 0.375     , 0.4981685 , 1.        ,
#         0.41666667],
#        [0.        , 1.        , 0.25      , 0.24175824, 0.26049419,
#         0.16904762],
#        [1.        , 0.8       , 0.25      , 0.51648352, 0.74426913,
#         0.88095238],
#        [1.        , 1.        , 1.        , 0.46886447, 0.49121762,
#         0.47142857],
#        [0.        , 0.        , 0.375     , 0.82417582, 0.22328074,
#         1.        ],
#        [0.        , 1.        , 0.5       , 0.57509158, 0.71449836,
#         0.60952381],
#        [1.        , 1.        , 0.875     , 0.29304029, 0.69217029,
#         0.28571429],
#        [0.        , 0.6       , 0.75      , 0.4981685 , 0.56564454,
#         0.51428571],
#        [1.        , 1.        , 0.5       , 0.3992674 , 0.28282227,
#         0.46190476],
#        [1.        , 1.        , 0.75      , 0.48717949, 0.29770765,
#         0.07142857],
#        [1.        , 0.8       , 0.25      , 0.4981685 , 0.21583805,
#         0.14285714],
#        [0.        , 1.        , 0.75      , 0.3040293 , 0.57308723,
#         0.42142857],
#        [1.        , 0.8       , 0.625     , 0.21978022, 0.63262876,
#         0.44047619],
#        [1.        , 0.8       , 0.        , 0.70695971, 0.58052992,
#         0.54047619],
#        [0.        , 1.        , 0.625     , 0.41391941, 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.75      , 0.42124542, 0.37213456,
#         0.35714286],
#        [1.        , 1.        , 0.625     , 0.84249084, 0.47633224,
#         0.45238095],
#        [0.        , 0.8       , 0.5       , 0.4981685 , 0.58797261,
#         0.31428571],
#        [0.        , 1.        , 0.25      , 0.24175824, 0.14885383,
#         0.        ],
#        [0.        , 1.        , 0.625     , 0.25274725, 0.        ,
#         0.97619048],
#        [1.        , 0.8       , 0.375     , 0.52014652, 0.56564454,
#         0.67142857],
#        [1.        , 1.        , 0.375     , 0.61538462, 0.74426913,
#         0.52380952],
#        [1.        , 1.        , 0.75      , 0.42124542, 0.61030068,
#         0.48809524],
#        [1.        , 0.8       , 0.        , 0.72527473, 0.55075915,
#         0.41666667],
#        [0.        , 0.8       , 0.625     , 0.4981685 , 0.81869604,
#         0.67857143],
#        [0.        , 0.8       , 0.625     , 0.31868132, 0.26793689,
#         0.39761905],
#        [1.        , 0.8       , 0.375     , 0.68498168, 0.29770765,
#         0.3452381 ],
#        [0.        , 1.        , 0.25      , 0.24175824, 0.46144686,
#         0.44047619],
#        [1.        , 0.8       , 0.        , 0.72527473, 0.38701995,
#         0.26666667],
#        [0.        , 0.        , 0.375     , 0.82417582, 0.5954153 ,
#         0.77380952],
#        [0.        , 0.8       , 0.375     , 0.87545788, 0.45400417,
#         0.58333333],
#        [0.        , 0.8       , 0.5       , 0.34065934, 0.96010717,
#         0.34761905],
#        [0.        , 1.        , 0.5       , 0.57509158, 0.23816612,
#         0.22619048],
#        [1.        , 0.8       , 0.625     , 0.33699634, 0.87823757,
#         0.57142857],
#        [1.        , 0.6       , 1.        , 0.19047619, 0.46144686,
#         0.41190476],
#        [0.        , 0.8       , 0.625     , 0.4981685 , 0.67728491,
#         0.43809524],
#        [1.        , 1.        , 0.75      , 0.92673993, 0.37213456,
#         0.19047619],
#        [0.        , 0.8       , 0.625     , 0.4981685 , 0.33492111,
#         0.1952381 ],
#        [0.        , 0.8       , 0.625     , 0.27472527, 0.43167609,
#         0.3047619 ],
#        [1.        , 0.8       , 0.375     , 0.52014652, 0.55820185,
#         0.43571429],
#        [0.        , 0.8       , 0.625     , 0.31135531, 0.61774338,
#         0.76190476],
#        [1.        , 0.8       , 0.625     , 0.5970696 , 0.34980649,
#         0.39285714],
#        [1.        , 1.        , 0.5       , 0.32600733, 0.74426913,
#         0.76190476],
#        [1.        , 1.        , 0.875     , 0.29304029, 0.5954153 ,
#         1.        ],
#        [0.        , 0.8       , 0.375     , 0.73626374, 1.        ,
#         0.61904762],
#        [1.        , 0.8       , 0.375     , 0.52014652, 0.55820185,
#         0.32142857],
#        [0.        , 1.        , 0.75      , 0.3040293 , 0.14885383,
#         0.4047619 ],
#        [1.        , 0.8       , 0.25      , 0.51648352, 0.66984221,
#         0.40952381],
#        [1.        , 0.8       , 0.625     , 0.5970696 , 0.74426913,
#         0.52380952],
#        [1.        , 1.        , 0.75      , 0.92673993, 0.27537958,
#         0.38571429],
#        [1.        , 1.        , 1.        , 0.46886447, 0.37213456,
#         1.        ],
#        [1.        , 0.4       , 0.25      , 0.47985348, 0.92289372,
#         0.66904762],
#        [0.        , 0.        , 0.375     , 0.82417582, 0.38701995,
#         0.31428571],
#        [1.        , 1.        , 0.75      , 0.42124542, 1.        ,
#         1.        ],
#        [0.        , 0.8       , 0.25      , 1.        , 0.98987794,
#         0.51190476],
#        [1.        , 0.4       , 0.875     , 0.49450549, 0.63262876,
#         0.51666667],
#        [1.        , 0.2       , 0.625     , 0.7032967 , 0.65495683,
#         0.67857143],
#        [0.        , 0.8       , 0.25      , 1.        , 0.46144686,
#         0.34285714],
#        [0.        , 0.6       , 0.75      , 0.4981685 , 0.49121762,
#         0.35      ],
#        [0.        , 0.8       , 0.5       , 0.34065934, 0.37213456,
#         0.35714286],
#        [1.        , 0.8       , 0.        , 0.72527473, 0.63262876,
#         0.6547619 ],
#        [0.        , 1.        , 0.75      , 0.57875458, 0.43167609,
#         0.55952381]])

# %% [markdown]
# <div style="text-align: right"> <font size=5>
#     <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a>
# </font></div>
#
# ---
#
# <div style="text-align: right"> <font size=6><i class="fa fa-coffee" aria-hidden="true" style="color:#004D7F"></i> </font></div>

# %%
# Codigo para crea un conjunto de datos y usarlos en la validación del modelo  en pasos adelante.
datos = dataset.drop(dataset.columns[:3], axis=1)

# %% [markdown]
# **Primer Modelo**: Se crea el primer modelo  "model_1a", sin usar hiperparametros y se ajusta con los datos de entrenamiento

# %%
# Se crea el modelo 1 sin usar Hiperparamtros
from sklearn.tree import DecisionTreeRegressor

# Crear un árbol de decisión y ajustarlo a los datos de entrenamiento
model_1a = DecisionTreeRegressor(criterion='absolute_error', max_depth=7)
model_1a.fit(X_train, y_train)

# hacer predicciones con los datos de entrenamiento
y_pred_entrenamiento = model_1a.predict(X_train)
y_pred_entrenamiento
# Out:
# array([10.8  , 11.335,  8.87 ,  9.33 ,  9.42 , 10.9  ,  8.87 , 10.   ,
#         5.   ,  7.   ,  8.87 , 14.   ,  6.875,  9.42 ,  7.8  , 12.55 ,
#        12.55 ,  7.   ,  9.33 ,  7.8  ,  7.   ,  7.   ,  6.   , 16.   ,
#         7.   ,  7.   ,  7.   ,  7.8  ,  8.87 ,  8.87 ,  7.645,  7.   ,
#         7.86 ,  8.355, 11.335,  9.42 , 12.55 , 14.   ,  8.355,  7.   ,
#         7.   ,  9.33 ,  8.87 ,  7.   ,  7.8  ,  7.625,  5.5  ,  6.325,
#         8.87 ,  5.555,  7.8  ,  7.   , 10.405,  7.   ,  6.21 ,  6.875,
#         7.   ,  3.93 ,  8.26 ,  5.   ,  9.33 ,  6.325,  9.33 ,  9.42 ,
#         7.   ,  7.8  ,  7.   ,  7.625,  6.69 , 14.   ,  8.87 ,  7.   ,
#         7.   ,  6.   ,  4.085,  9.42 ,  9.42 ,  8.87 ,  9.42 ,  7.8  ,
#        11.29 ,  8.87 , 11.   ,  6.875,  9.42 ,  5.555, 14.   ,  5.375,
#         7.   ,  7.   ,  8.26 ,  8.26 ,  8.87 ,  7.   ,  6.21 ,  8.355,
#         8.87 ,  2.   ,  8.87 ,  2.17 ,  7.   ,  7.   ,  9.33 ,  9.42 ,
#         2.   ,  4.   ,  8.87 ,  4.   ,  7.8  ,  4.04 ,  9.33 ,  7.8  ,
#         6.   ,  9.33 ,  6.   ,  5.555,  7.   ,  6.   ,  8.26 ,  8.87 ,
#         4.085,  6.   ,  6.   ,  7.   ,  7.   ,  7.8  ,  3.48 ,  6.69 ,
#        11.   ,  6.69 ,  8.87 ,  8.87 ,  7.   ,  9.33 ,  7.   ,  7.8  ,
#         7.   ,  9.42 ,  4.5  ,  8.87 ,  7.   ,  7.8  ,  7.   ,  9.42 ,
#         6.875, 11.   ,  9.33 ,  9.42 ,  7.   ,  6.   ,  7.   , 10.145,
#         8.355,  7.   ,  8.87 ,  9.42 ,  9.42 ,  8.87 ,  7.   ,  7.   ,
#         9.43 ,  9.33 ,  7.   ,  9.42 ,  9.42 , 15.2  ,  9.43 ,  5.   ,
#        11.335,  6.   ,  6.   ,  9.43 ,  8.87 ,  6.875,  7.8  ,  3.93 ,
#         6.82 ,  7.645,  7.   ,  5.375,  7.8  ,  9.43 ,  7.   ,  9.42 ,
#         7.8  ,  7.   ,  5.375,  7.   ,  9.33 ,  8.87 ,  9.33 ,  8.87 ,
#         8.87 ,  8.87 ,  6.69 ,  5.375,  6.875,  9.42 , 12.55 ,  3.93 ,
#         5.   ,  5.   ,  7.   ,  8.26 ,  8.87 ,  8.26 ,  8.87 ,  5.375,
#         6.33 ,  6.   ,  5.555,  7.8  ,  6.66 ,  8.355,  9.42 ,  9.42 ,
#         7.   ,  6.   ,  7.645, 10.405,  9.42 ,  7.8  ,  9.43 ,  9.42 ,
#         7.8  ,  8.355,  8.87 ,  7.   ,  7.8  , 16.   ,  7.   ,  7.645,
#         6.875,  7.   ,  9.33 ,  7.8  ,  9.42 ,  8.5  ,  4.   ,  9.33 ,
#         9.17 ,  7.8  ,  7.   ,  5.375,  9.42 , 16.   ,  6.875,  8.87 ,
#         5.375,  9.42 ,  2.   ,  8.26 ,  7.   ,  7.   ,  9.42 , 10.37 ,
#         9.42 ,  7.   ,  7.   ,  7.   ,  3.93 ,  8.26 ,  7.8  , 14.   ,
#         2.   ,  9.42 ,  7.   ,  3.64 ,  7.   ,  8.87 ,  2.   , 12.55 ,
#         5.375, 11.29 ,  7.   , 10.9  ,  6.875,  5.375,  7.   ,  7.   ,
#         7.   ,  2.   ,  7.   ,  9.43 ,  7.   ,  8.87 ,  9.42 ,  8.26 ,
#         7.   ,  9.43 ,  7.   ,  5.375,  9.42 ,  9.33 ,  7.   ,  4.   ,
#         9.42 ,  7.   ,  5.5  ,  7.   ,  7.8  ,  6.875,  6.33 ,  3.6  ,
#         2.   ,  7.   ,  7.   ,  9.42 ,  9.42 ,  7.   ,  8.87 ,  7.645,
#         5.555,  5.09 ,  7.   ,  8.87 ,  8.87 ,  3.625, 10.9  ,  9.33 ,
#         9.43 , 11.29 ,  7.   ,  8.26 ,  9.42 ,  7.8  ,  7.   ,  7.   ,
#         7.   ,  8.87 ,  7.   ,  9.33 ,  8.26 ,  9.43 ,  7.8  ,  9.17 ,
#         2.335,  9.42 ,  9.33 , 16.   ,  4.085,  8.   ,  7.   ,  9.42 ,
#         8.87 ,  8.355, 10.9  ,  6.   ,  7.   ,  9.43 ,  3.93 ,  7.   ,
#         9.42 ,  7.   ,  7.8  ,  8.87 ,  4.25 ,  7.   ,  8.87 ,  9.33 ,
#         9.33 ,  9.33 ,  8.87 ,  5.09 ,  7.   ,  6.   , 10.8  ,  8.87 ,
#         8.26 ,  6.   ,  9.33 , 11.   ,  8.87 ,  8.26 ,  9.42 ,  7.   ,
#         8.26 ,  2.   ,  8.87 ,  9.33 ,  7.   , 12.55 ,  7.   ,  9.43 ,
#         7.   ,  9.42 ,  7.8  ,  4.25 ,  7.   , 10.37 ,  7.8  ,  3.93 ,
#         7.625, 10.37 , 10.37 , 11.335, 12.55 ,  8.87 ,  8.87 ,  7.625,
#         8.26 ,  8.87 ,  9.42 ,  7.   ,  7.   ,  9.33 ,  7.8  , 10.8  ,
#         7.625,  8.355,  8.87 ,  6.   ,  6.   ,  8.26 ,  9.42 ,  8.87 ,
#         6.   ,  7.67 ,  9.43 ,  4.5  ,  7.   ,  5.375,  9.42 , 12.55 ,
#        12.55 ,  9.43 ,  9.43 ,  2.   ,  7.8  ,  7.   ,  8.87 ,  7.   ,
#         7.8  ,  8.87 , 11.335,  6.875,  2.   ,  7.8  ,  9.42 ,  9.42 ,
#         3.625,  8.87 ,  8.355,  7.8  ,  8.26 ,  8.5  ,  5.14 ,  9.43 ,
#         8.87 ,  3.93 ,  6.69 ,  9.42 ,  7.625,  6.875, 10.   ,  7.   ,
#         8.87 ,  9.33 ,  9.17 ,  7.645,  3.93 ,  8.87 ,  7.8  ,  9.33 ,
#         7.   ,  7.   , 11.335,  6.82 ,  8.87 , 11.   ,  6.33 ,  7.   ,
#         6.325,  7.   , 14.   , 11.29 ,  6.875,  8.87 ,  7.   ,  8.   ,
#         4.085,  7.645,  9.42 ,  8.87 ,  9.33 , 10.9  ,  9.33 ,  6.33 ,
#         4.   ,  7.645,  8.87 ,  6.21 ,  7.   ,  7.   ,  8.26 ,  7.   ,
#        11.29 ,  7.8  ,  7.   ,  4.   ,  9.42 ,  9.43 ,  8.87 ,  9.43 ,
#         8.87 ,  6.67 ,  9.42 ,  7.   ,  9.33 ,  4.04 ,  9.42 ,  7.8  ,
#         5.09 ,  7.   ,  1.01 ,  9.33 ,  3.93 ,  5.375,  9.43 ,  9.42 ,
#         6.325,  7.   ,  7.645,  7.   ,  8.355,  5.2  ,  6.875, 11.29 ,
#         9.43 , 10.   ,  7.   ,  9.42 ,  6.33 ,  9.42 ,  5.   ,  7.   ,
#         3.93 , 11.75 ,  7.   ,  3.93 ,  7.   ,  7.8  ,  9.33 ,  5.   ,
#         7.   ,  6.875,  7.   ,  6.   ,  9.33 ,  7.   ,  7.8  ,  7.   ,
#         4.   ,  7.   ,  7.   ,  3.93 ,  8.87 ,  7.   ,  9.42 ,  9.43 ,
#         6.875,  9.33 ,  2.   , 10.8  ,  7.8  ,  6.33 ,  8.26 ,  5.375,
#         9.33 ,  4.25 ,  7.645,  3.93 ,  7.   ,  7.   ,  8.87 , 14.   ,
#         7.8  ,  9.33 ,  9.33 ,  9.42 ,  4.   , 12.55 ,  8.87 ,  8.26 ,
#         7.8  , 11.   ,  9.42 ,  6.875,  9.42 ,  6.875,  4.085,  7.   ,
#         7.   ,  6.   ,  7.645,  9.42 ,  8.26 ,  7.625,  8.5  ,  7.   ,
#         5.375,  7.   ,  9.42 ,  9.33 ,  7.   ,  8.87 ,  5.2  ,  8.26 ,
#         7.   ,  7.625,  9.33 , 10.37 ,  9.33 ,  8.87 ,  6.325,  5.   ,
#        11.29 ,  8.87 , 14.   ,  7.   ,  7.   ,  9.42 ,  7.   ,  3.93 ,
#         6.21 ,  7.   ,  9.43 ,  9.33 ,  1.01 ,  9.43 ,  8.87 ,  6.875,
#         6.875, 12.55 ,  7.   ,  9.43 ,  3.67 ,  7.   ,  7.8  ,  7.625,
#         6.82 ,  7.625,  7.625,  7.   ,  8.87 , 10.2  ,  9.42 ,  7.625,
#         4.25 ,  7.   ,  9.42 , 12.55 ,  7.8  , 10.9  ,  8.87 ,  6.875,
#        14.   ,  9.42 ,  9.42 , 14.   , 11.   ,  7.8  , 10.37 ,  7.   ,
#         6.   ,  5.555,  6.325,  8.87 , 10.   ,  8.87 ,  2.17 ,  6.21 ,
#         9.42 ,  7.8  ,  6.325, 14.   ,  9.42 , 16.   ,  8.87 , 12.55 ,
#         2.335,  7.   ,  8.87 ,  9.33 ,  6.   ,  8.26 , 11.29 ,  8.87 ,
#        11.335,  9.42 ,  8.355,  7.   ,  8.26 ,  8.87 ,  7.   ,  7.   ,
#         9.42 ,  8.87 ,  7.   ,  9.42 ,  9.33 ,  7.   ,  5.555,  7.   ,
#         9.42 ,  8.87 ,  7.   ,  5.   ,  7.   ,  2.   ,  6.   ,  8.87 ,
#         9.17 ,  9.42 ,  7.   ,  8.87 , 14.   ,  6.   ,  9.42 ,  5.   ,
#         7.   ,  6.69 ,  4.25 ,  7.8  ,  6.   ,  9.42 ,  9.42 ,  7.   ,
#         8.87 ,  7.8  , 11.   ,  4.25 ,  6.   ,  7.   ,  5.   ,  9.33 ,
#         9.43 ,  7.   ,  7.   ,  6.   , 10.37 ,  6.82 ,  7.   ,  9.42 ,
#         9.33 ,  7.   ,  7.   ,  5.   ,  4.38 ,  5.375,  5.555,  5.555,
#         8.87 ,  1.8  ,  7.   ,  9.17 ,  8.87 ,  7.   ,  8.87 ,  8.87 ,
#         7.   ,  9.33 ,  7.   ,  9.17 ,  7.645,  6.   ,  9.42 ,  8.26 ,
#        14.   ,  8.87 ,  8.26 ,  5.375,  8.355,  5.375,  8.26 ,  7.   ,
#         4.085,  7.   ,  5.375,  9.42 ,  9.43 , 11.29 ,  7.8  ,  3.93 ,
#         7.8  ,  8.26 ,  7.   ,  7.   ,  7.   ,  8.26 ,  8.26 ,  9.33 ,
#         6.   ,  8.87 ,  3.   , 11.335,  5.   ,  5.375,  9.42 ,  9.33 ,
#         8.87 ,  6.875,  7.   ,  5.375,  9.42 ,  3.93 ,  5.   , 14.   ,
#        11.335,  5.09 ,  7.   ,  5.555,  5.2  ,  2.   ,  8.87 ,  7.   ,
#         7.645,  9.42 ,  9.42 , 10.145,  7.   ,  7.   ,  7.8  ,  7.   ,
#         9.33 ,  9.42 ,  4.   ,  9.43 ,  2.17 ,  9.33 ,  8.26 ,  7.625,
#         8.87 ,  9.42 ,  7.   ,  8.26 ,  8.87 ,  7.   ,  7.   , 11.335,
#         8.87 ,  2.   ,  8.87 ,  8.87 ,  6.875, 10.   ,  7.   ,  7.   ,
#         8.26 ,  9.43 , 14.   ,  8.26 ,  8.87 ,  8.87 ,  7.   ,  9.33 ,
#         6.875,  8.26 ,  9.42 ,  8.87 ,  7.   ,  7.645, 13.   ,  9.42 ,
#         7.8  ,  6.325,  9.42 ,  7.8  ,  9.42 ,  8.87 ,  6.   ,  9.43 ,
#         7.8  ,  8.87 ,  7.   ,  7.625,  9.43 ,  6.82 ,  5.   ,  5.   ,
#         5.   ,  7.   ,  7.   ,  7.   ,  9.42 ])

# %%
# Hacer predicciones en los datos de prueba o Validación.
y_pred_test = model_1a.predict(X_test)
y_pred_test
# Out:
# array([ 5.   ,  2.   ,  7.   ,  5.555,  6.   ,  7.   ,  6.875,  8.26 ,
#         7.645, 11.75 ,  9.33 ,  9.42 ,  3.93 ,  7.8  ,  7.8  ,  5.09 ,
#         8.26 ,  7.625,  5.375,  7.   ,  7.8  , 10.8  ,  8.87 ,  8.87 ,
#         7.   ,  8.87 ,  7.   ,  8.87 ,  4.   , 12.55 , 15.2  ,  9.42 ,
#         6.325,  9.42 ,  8.26 ,  8.87 ,  8.26 , 10.9  ,  6.82 ,  7.8  ,
#         8.26 , 11.335,  5.555,  4.25 ,  9.42 ,  9.33 ,  3.93 ,  3.93 ,
#         8.87 ,  8.87 ,  9.42 , 11.   ,  7.   ,  8.26 ,  7.   ,  2.   ,
#         9.33 ,  7.8  ,  9.42 ,  9.42 ,  8.87 ,  6.875,  7.   ,  7.625,
#         5.   ,  7.   ,  7.8  ,  7.   , 10.9  ,  5.375,  6.875, 13.   ,
#         8.87 ,  6.   ,  5.375,  7.   ,  8.87 ,  7.   ,  7.   ,  7.8  ,
#         7.   , 14.   ,  4.   , 13.   ,  8.87 ,  9.42 ,  7.   ,  8.26 ,
#         7.8  ,  7.   , 11.   , 16.   ,  9.42 ,  9.43 , 10.405,  7.67 ,
#         7.   ,  7.8  ,  7.   ])

# %% [markdown]
# **MAE - Error Absoluto Medio:** s una métrica comúnmente utilizada para evaluar la precisión de modelos de regresión, incluidos los modelos de árboles de decisión.
#
# El MAE se calcula como el promedio de las diferencias absolutas entre las predicciones del modelo y los valores reales. En términos simples, el MAE mide la magnitud promedio de los errores en las predicciones del modelo, sin considerar la dirección de los errores.
#
# Para un modelo de árbol de decisión, el MAE se calcula de la siguiente manera:
#
# a: Se hace una predicción para cada ejemplo en el conjunto de datos de prueba usando el modelo de árbol de decisión.
#
# b: Se calcula la diferencia absoluta entre la predicción y el valor real para cada ejemplo.
#
# c: Se toma el promedio de todas estas diferencias absolutas.
#
# Para mayor información:
# https://statologos.com/calculadora-del-error-medio-absoluto/

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test , y_pred_test)
rmse = np.sqrt(mse)
MAE= mae(y_test , y_pred_test)

# %%
# Imprimir las métricas
print("Error Cuadrático Medio (MSE):", mse)
print("Raíz del Error Cuadrático Medio (RMSE):", rmse)
print("Error Absoluto Medio (MAE):", MAE)
# Out:
# Error Cuadrático Medio (MSE): 11.653888383838387
# Raíz del Error Cuadrático Medio (RMSE): 3.4137791937731397
# Error Absoluto Medio (MAE): 2.53959595959596

# %%
# calcular el MAE de entrenamiento con cros Validation
from sklearn.model_selection import cross_val_score
mae_train_m1 = -1 * cross_val_score(model_1a, X_train,y_train, cv=5, scoring='neg_mean_absolute_error').mean()

print("Error Absoluto Medio (MAE):", mae_train_m1)
# Out:
# Error Absoluto Medio (MAE): 2.5255536723163843

# %% [markdown]
# **Predicciones**: Se hacen las respectivas predicciones, donde se cita la variables y_pred_test -  y se compara con los valores reales de validación.

# %%
# Se crea un dataframe con las predicciones y el valor real
df_predicciones = pd.DataFrame({'TotalHotasReales' : y_test, 'TotalPrediccion' : y_pred_test})
df_predicciones.head(122)
# Out:
#      TotalHotasReales  TotalPrediccion
# 166               6.0              5.0
# 392               2.0              2.0
# 40                1.0              7.0
# 118               9.8              5.6
# 953               6.8              6.0
# ..                ...              ...
# 146               5.7             10.4
# 891              11.8              7.7
# 867              16.0              7.0
# 93                7.0              7.8
# 450              10.5              7.0
#
# [99 rows x 2 columns]

# %%
# Se crea un dataframe con las predicciones y el valor real
df_predicciones4 = pd.DataFrame({'TotalHotasReales' : y_train, 'TotalPrediccion' : y_pred_entrenamiento})
df_predicciones4.head(111)
# Out:
#      TotalHotasReales  TotalPrediccion
# 917               5.9             10.8
# 241              14.0             11.3
# 571              10.5              8.9
# 732              11.0              9.3
# 495               7.5              9.4
# ..                ...              ...
# 355              13.1              8.9
# 873               3.0              4.0
# 780              15.4              7.8
# 569               4.0              4.0
# 397               4.8              9.3
#
# [111 rows x 2 columns]

# %% [markdown]
# **Se crea un gráfico del arbol que se genera para este caso**: Se observa que la profundidad es de 7 y tiene un total de 93 Nodos.

# %%
from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(16, 5))

print(f"Profundidad del árbol: {model_1a.get_depth()}")
print(f"Número de nodos terminales: {model_1a.get_n_leaves()}")

plot = plot_tree(
            decision_tree = model_1a,
            feature_names = dataset.drop(columns = "HH_En_la_Maquina").columns,
            class_names   = 'HH_En_la_Maquina',
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 7
# Número de nodos terminales: 93

# %%
from sklearn.tree import export_text
texto_modelo = export_text(
                    decision_tree = model_1a,
                    feature_names = list(dataset.drop(columns = "HH_En_la_Maquina").columns)
               )
print(texto_modelo)
# Out:
# |--- Otras_HH <= 0.32
# |   |--- Otras_HH <= 0.17
# |   |   |--- Epocadelanio <= 0.50
# |   |   |   |--- HH_Actv_Gnerales <= 0.04
# |   |   |   |   |--- value: [11.00]
# |   |   |   |--- HH_Actv_Gnerales >  0.04
# |   |   |   |   |--- Ready_Backlog <= 0.66
# |   |   |   |   |   |--- Otras_HH <= 0.08
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.24
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.24
# |   |   |   |   |   |   |   |--- value: [5.50]
# |   |   |   |   |   |--- Otras_HH >  0.08
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.29
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.29
# |   |   |   |   |   |   |   |--- value: [5.09]
# |   |   |   |   |--- Ready_Backlog >  0.66
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.28
# |   |   |   |   |   |   |--- Otras_HH <= 0.13
# |   |   |   |   |   |   |   |--- value: [2.33]
# |   |   |   |   |   |   |--- Otras_HH >  0.13
# |   |   |   |   |   |   |   |--- value: [3.48]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.28
# |   |   |   |   |   |   |--- value: [8.00]
# |   |   |--- Epocadelanio >  0.50
# |   |   |   |--- Otras_HH <= 0.06
# |   |   |   |   |--- Cumplimiento_Estrategia <= 0.90
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.67
# |   |   |   |   |   |   |--- Cumplimiento_Programa <= 0.19
# |   |   |   |   |   |   |   |--- value: [1.01]
# |   |   |   |   |   |   |--- Cumplimiento_Programa >  0.19
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.67
# |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |--- Cumplimiento_Estrategia >  0.90
# |   |   |   |   |   |--- Ready_Backlog <= 0.44
# |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |--- Ready_Backlog >  0.44
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.07
# |   |   |   |   |   |   |   |--- value: [3.62]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.07
# |   |   |   |   |   |   |   |--- value: [2.17]
# |   |   |   |--- Otras_HH >  0.06
# |   |   |   |   |--- HH_Actv_Gnerales <= 0.32
# |   |   |   |   |   |--- Otras_HH <= 0.15
# |   |   |   |   |   |   |--- Cumplimiento_Programa <= 0.94
# |   |   |   |   |   |   |   |--- value: [3.93]
# |   |   |   |   |   |   |--- Cumplimiento_Programa >  0.94
# |   |   |   |   |   |   |   |--- value: [2.00]
# |   |   |   |   |   |--- Otras_HH >  0.15
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.49
# |   |   |   |   |   |   |   |--- value: [4.08]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.49
# |   |   |   |   |   |   |   |--- value: [5.20]
# |   |   |   |   |--- HH_Actv_Gnerales >  0.32
# |   |   |   |   |   |--- Otras_HH <= 0.15
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.43
# |   |   |   |   |   |   |   |--- value: [6.69]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.43
# |   |   |   |   |   |   |   |--- value: [3.00]
# |   |   |   |   |   |--- Otras_HH >  0.15
# |   |   |   |   |   |   |--- Otras_HH <= 0.16
# |   |   |   |   |   |   |   |--- value: [3.67]
# |   |   |   |   |   |   |--- Otras_HH >  0.16
# |   |   |   |   |   |   |   |--- value: [4.04]
# |   |--- Otras_HH >  0.17
# |   |   |--- Otras_HH <= 0.23
# |   |   |   |--- HH_Actv_Gnerales <= 0.02
# |   |   |   |   |--- value: [10.00]
# |   |   |   |--- HH_Actv_Gnerales >  0.02
# |   |   |   |   |--- Epocadelanio <= 0.50
# |   |   |   |   |   |--- Cumplimiento_Programa <= 0.31
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.24
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.24
# |   |   |   |   |   |   |   |--- value: [6.82]
# |   |   |   |   |   |--- Cumplimiento_Programa >  0.31
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.15
# |   |   |   |   |   |   |   |--- value: [3.60]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.15
# |   |   |   |   |   |   |   |--- value: [5.38]
# |   |   |   |   |--- Epocadelanio >  0.50
# |   |   |   |   |   |--- Otras_HH <= 0.23
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.31
# |   |   |   |   |   |   |   |--- value: [10.80]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.31
# |   |   |   |   |   |   |   |--- value: [6.00]
# |   |   |   |   |   |--- Otras_HH >  0.23
# |   |   |   |   |   |   |--- Cumplimiento_Estrategia <= 0.70
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |--- Cumplimiento_Estrategia >  0.70
# |   |   |   |   |   |   |   |--- value: [4.38]
# |   |   |--- Otras_HH >  0.23
# |   |   |   |--- HH_Actv_Gnerales <= 0.98
# |   |   |   |   |--- Ready_Backlog <= 0.95
# |   |   |   |   |   |--- Cumplimiento_Programa <= 0.81
# |   |   |   |   |   |   |--- Otras_HH <= 0.32
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- Otras_HH >  0.32
# |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |--- Cumplimiento_Programa >  0.81
# |   |   |   |   |   |   |--- Otras_HH <= 0.29
# |   |   |   |   |   |   |   |--- value: [4.25]
# |   |   |   |   |   |   |--- Otras_HH >  0.29
# |   |   |   |   |   |   |   |--- value: [6.21]
# |   |   |   |   |--- Ready_Backlog >  0.95
# |   |   |   |   |   |--- Otras_HH <= 0.30
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.98
# |   |   |   |   |   |   |   |--- value: [10.20]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.98
# |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |--- Otras_HH >  0.30
# |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |--- HH_Actv_Gnerales >  0.98
# |   |   |   |   |--- value: [15.20]
# |--- Otras_HH >  0.32
# |   |--- HH_Actv_Gnerales <= 0.51
# |   |   |--- Otras_HH <= 0.42
# |   |   |   |--- Otras_HH <= 0.36
# |   |   |   |   |--- Cumplimiento_Programa <= 0.69
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.23
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.19
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.19
# |   |   |   |   |   |   |   |--- value: [6.00]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.23
# |   |   |   |   |   |   |--- Cumplimiento_Programa <= 0.25
# |   |   |   |   |   |   |   |--- value: [10.40]
# |   |   |   |   |   |   |--- Cumplimiento_Programa >  0.25
# |   |   |   |   |   |   |   |--- value: [7.62]
# |   |   |   |   |--- Cumplimiento_Programa >  0.69
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.37
# |   |   |   |   |   |   |--- Otras_HH <= 0.34
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |--- Otras_HH >  0.34
# |   |   |   |   |   |   |   |--- value: [11.75]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.37
# |   |   |   |   |   |   |--- value: [7.67]
# |   |   |   |--- Otras_HH >  0.36
# |   |   |   |   |--- Otras_HH <= 0.42
# |   |   |   |   |   |--- Otras_HH <= 0.40
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.26
# |   |   |   |   |   |   |   |--- value: [6.00]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.26
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |--- Otras_HH >  0.40
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.33
# |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.33
# |   |   |   |   |   |   |   |--- value: [9.17]
# |   |   |   |   |--- Otras_HH >  0.42
# |   |   |   |   |   |--- Cumplimiento_Programa <= 0.69
# |   |   |   |   |   |   |--- Cumplimiento_Programa <= 0.56
# |   |   |   |   |   |   |   |--- value: [4.50]
# |   |   |   |   |   |   |--- Cumplimiento_Programa >  0.56
# |   |   |   |   |   |   |   |--- value: [3.64]
# |   |   |   |   |   |--- Cumplimiento_Programa >  0.69
# |   |   |   |   |   |   |--- Cumplimiento_Programa <= 0.81
# |   |   |   |   |   |   |   |--- value: [6.67]
# |   |   |   |   |   |   |--- Cumplimiento_Programa >  0.81
# |   |   |   |   |   |   |   |--- value: [6.66]
# |   |   |--- Otras_HH >  0.42
# |   |   |   |--- Cumplimiento_Programa <= 0.31
# |   |   |   |   |--- HH_Actv_Gnerales <= 0.24
# |   |   |   |   |   |--- value: [1.80]
# |   |   |   |   |--- HH_Actv_Gnerales >  0.24
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.42
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.84
# |   |   |   |   |   |   |   |--- value: [7.64]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.84
# |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.42
# |   |   |   |   |   |   |--- Otras_HH <= 0.66
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |--- Otras_HH >  0.66
# |   |   |   |   |   |   |   |--- value: [10.14]
# |   |   |   |--- Cumplimiento_Programa >  0.31
# |   |   |   |   |--- Ready_Backlog <= 0.45
# |   |   |   |   |   |--- Ready_Backlog <= 0.44
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.50
# |   |   |   |   |   |   |   |--- value: [9.33]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.50
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |--- Ready_Backlog >  0.44
# |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |--- Ready_Backlog >  0.45
# |   |   |   |   |   |--- Cumplimiento_Estrategia <= 0.50
# |   |   |   |   |   |   |--- Otras_HH <= 0.48
# |   |   |   |   |   |   |   |--- value: [8.36]
# |   |   |   |   |   |   |--- Otras_HH >  0.48
# |   |   |   |   |   |   |   |--- value: [11.34]
# |   |   |   |   |   |--- Cumplimiento_Estrategia >  0.50
# |   |   |   |   |   |   |--- Epocadelanio <= 0.50
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- Epocadelanio >  0.50
# |   |   |   |   |   |   |   |--- value: [8.26]
# |   |--- HH_Actv_Gnerales >  0.51
# |   |   |--- HH_Actv_Gnerales <= 0.96
# |   |   |   |--- Otras_HH <= 0.57
# |   |   |   |   |--- Cumplimiento_Programa <= 0.94
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.93
# |   |   |   |   |   |   |--- Otras_HH <= 0.48
# |   |   |   |   |   |   |   |--- value: [8.87]
# |   |   |   |   |   |   |--- Otras_HH >  0.48
# |   |   |   |   |   |   |   |--- value: [9.42]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.93
# |   |   |   |   |   |   |--- value: [5.14]
# |   |   |   |   |--- Cumplimiento_Programa >  0.94
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.53
# |   |   |   |   |   |   |--- value: [7.86]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.53
# |   |   |   |   |   |   |--- Otras_HH <= 0.51
# |   |   |   |   |   |   |   |--- value: [10.37]
# |   |   |   |   |   |   |--- Otras_HH >  0.51
# |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |--- Otras_HH >  0.57
# |   |   |   |   |--- Cumplimiento_Programa <= 0.56
# |   |   |   |   |   |--- Otras_HH <= 0.62
# |   |   |   |   |   |   |--- Otras_HH <= 0.58
# |   |   |   |   |   |   |   |--- value: [8.36]
# |   |   |   |   |   |   |--- Otras_HH >  0.58
# |   |   |   |   |   |   |   |--- value: [5.55]
# |   |   |   |   |   |--- Otras_HH >  0.62
# |   |   |   |   |   |   |--- Otras_HH <= 0.64
# |   |   |   |   |   |   |   |--- value: [11.29]
# |   |   |   |   |   |   |--- Otras_HH >  0.64
# |   |   |   |   |   |   |   |--- value: [7.80]
# |   |   |   |   |--- Cumplimiento_Programa >  0.56
# |   |   |   |   |   |--- Otras_HH <= 0.72
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.71
# |   |   |   |   |   |   |   |--- value: [9.43]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.71
# |   |   |   |   |   |   |   |--- value: [6.88]
# |   |   |   |   |   |--- Otras_HH >  0.72
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.70
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.70
# |   |   |   |   |   |   |   |--- value: [12.55]
# |   |   |--- HH_Actv_Gnerales >  0.96
# |   |   |   |--- Ready_Backlog <= 0.61
# |   |   |   |   |--- Otras_HH <= 0.47
# |   |   |   |   |   |--- Cumplimiento_Programa <= 0.69
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.53
# |   |   |   |   |   |   |   |--- value: [10.90]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.53
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |--- Cumplimiento_Programa >  0.69
# |   |   |   |   |   |   |--- Epocadelanio <= 0.50
# |   |   |   |   |   |   |   |--- value: [6.00]
# |   |   |   |   |   |   |--- Epocadelanio >  0.50
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |--- Otras_HH >  0.47
# |   |   |   |   |   |--- Otras_HH <= 0.85
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.10
# |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.10
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |--- Otras_HH >  0.85
# |   |   |   |   |   |   |--- Ready_Backlog <= 0.11
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- Ready_Backlog >  0.11
# |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |--- Ready_Backlog >  0.61
# |   |   |   |   |--- Ready_Backlog <= 0.73
# |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.98
# |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |--- HH_Actv_Gnerales >  0.98
# |   |   |   |   |   |   |--- HH_Actv_Gnerales <= 0.99
# |   |   |   |   |   |   |   |--- value: [6.33]
# |   |   |   |   |   |   |--- HH_Actv_Gnerales >  0.99
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |--- Ready_Backlog >  0.73
# |   |   |   |   |   |--- Ready_Backlog <= 0.87
# |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |--- Ready_Backlog >  0.87
# |   |   |   |   |   |   |--- value: [16.00]

# %% [markdown]
# **Importancia de las Variables predictoras:**

# %%
importancia_predictores = pd.DataFrame(
                            {'predictor': dataset.drop(columns = "HH_En_la_Maquina").columns,
                             'importancia': model_1a.feature_importances_}
                            )
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores.sort_values('importancia', ascending=False)
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#                  predictor  importancia
# 5                 Otras_HH      5.4e-01
# 4         HH_Actv_Gnerales      2.4e-01
# 3            Ready_Backlog      1.1e-01
# 2    Cumplimiento_Programa      7.0e-02
# 0             Epocadelanio      2.8e-02
# 1  Cumplimiento_Estrategia      1.4e-02

# %% [markdown]
# **Se crea un nuevo modelo usando hiperparametros**

# %%
# Valores de ccp_alpha evaluados
param_grid = {'ccp_alpha':np.linspace(0, 80, 20)}

# Búsqueda por validación cruzada
grid = GridSearchCV(
        # El árbol se crece al máximo posible para luego aplicar el pruning
        estimator = DecisionTreeRegressor(
                            max_depth         = None,
                            min_samples_split = 2,
                            min_samples_leaf  = 1,
                            random_state      = 123
                       ),
        param_grid = param_grid,
        cv         = 10,
        refit      = True,
        return_train_score = True
      )

grid.fit(X_train, y_train)

fig, ax = plt.subplots(figsize=(6, 3.84))
scores = pd.DataFrame(grid.cv_results_)
scores.plot(x='param_ccp_alpha', y='mean_train_score', yerr='std_train_score', ax=ax)
scores.plot(x='param_ccp_alpha', y='mean_test_score', yerr='std_test_score', ax=ax)
ax.set_title("Error de validacion cruzada vs hiperparámetro ccp_alpha");

# %%
grid.best_params_
# Out:
# {'ccp_alpha': 4.2105263157894735}

# %% [markdown]
# **Se crea el modelo** Y se crea la imagen del arbol final.

# %%
# Estructura del árbol final - "Modelofinal"
# ------------------------------------------------------------------------------

param_grid = {
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Creamos un modelo de árbol de decisión
tree = model_1a = DecisionTreeRegressor()

# Usamos GridSearchCV para encontrar la mejor combinación de hiperparámetros
modelo_final = GridSearchCV(tree, param_grid, cv=5)
modelo_final.fit(X_train, y_train)

# Mostramos los mejores hiperparámetros encontrados



# hacer predicciones con los datos de entrenamiento
Predicion_MF_entrenamiento = modelo_final.predict(X_train)
Predicion_MF_test = modelo_final.predict(X_test)

# %%
# Los mejores hiperparametros.
param_grid
# Out:
# {'max_depth': [3, 5, 7],
#  'min_samples_split': [2, 5, 10],
#  'min_samples_leaf': [1, 2, 4],
#  'max_features': ['sqrt', 'log2']}

# %% [markdown]
# **Comparacion del MAE para los dos modelos creados.**
#
# 1: MAE para modelo sin hiperparametros: 3.12
#
# 2: MAE: para el modelo con ajuste de hiperparametros: 3.12.
#
# Nota: El MAE mide la magnitud promedio de los errores en las predicciones de un modelo de regresión, sin tener en cuenta su dirección (es decir, si son sobreestimaciones o subestimaciones).
#
# Por lo tanto, un MAE más bajo indica que las predicciones del modelo están más cerca de los valores reales en el conjunto de datos de prueba. En otras palabras, cuanto más bajo sea el MAE, mejor será el ajuste del modelo a los datos observados y, por lo tanto, se considera un mejor rendimiento del modelo.
#
# fuente: ChatGPT

# %%
# calcular el MAE de entrenamiento con cros Validation  - COn Hiperparametros
from sklearn.model_selection import cross_val_score
mae_train_m2 = -1 * cross_val_score(modelo_final, X_train,y_train, cv=5, scoring='neg_mean_absolute_error').mean()
print("MAE de entrenamiento Cros Validation - Con Hiperparametros:", mae_train_m2)
print("MAE de entrenamiento Cros Validation - Sin Hiperparametros:", mae_train_m1)
# Out:
# MAE de entrenamiento Cros Validation - Con Hiperparametros: 2.3033079036491175
# MAE de entrenamiento Cros Validation - Sin Hiperparametros: 2.5255536723163843

# %% [markdown]
# **Conclusión**
#
# El modelo con ajuste de hiperparametros es mas eficiente para predecir las HH necesarias para trabajos correctivos en una empresa industrial.

# %%
# Se crea un dataframe con las predicciones y el valor real
df_predicciones5 = pd.DataFrame({'TotalHotasReales' : y_test, 'TotalPrediccion' : Predicion_MF_test
})
df_predicciones5.head(5)
# Out:
#      TotalHotasReales  TotalPrediccion
# 166               6.0              5.6
# 392               2.0              6.3
# 40                1.0              8.0
# 118               9.8              8.0
# 953               6.8              8.9
